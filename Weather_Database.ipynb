# %%
######################################## Deliverable 1: Retrieve Weather Data ########################################
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# 3. Create a new set of 2,000 random latitudes and longitudes.
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# 4. Get the nearest city using the citipy module.
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
# 6. Retrieve the following information from the API call:
# Import your Requests Library and the weather_api_key
from config import weather_api_key
import requests

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather['weather'][0]['main']
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country,
                          "Date": city_date})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | olafsvik
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | zhigansk
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | palaia fokaia
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | santa cruz
# Processing Record 10 of Set 1 | husavik
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | nizwa
# Processing Record 13 of Set 1 | ancud
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | thompson
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | asau
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | coihaique
# Processing Record 23 of Set 1 | oistins
# Processing Record 24 of Set 1 | pont-audemer
# Processing Record 25 of Set 1 | namibe
# Processing Record 26 of Set 1 | tateyama
# Processing Record 27 of Set 1 | atambua
# Processing Record 28 of Set 1 | sitka
# Processing Record 29 of Set 1 | barrow
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | college
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | pochutla
# Processing Record 34 of Set 1 | mosquera
# Processing Record 35 of Set 1 | farso
# Processing Record 36 of Set 1 | tome-acu
# City not found. Skipping...
# Processing Record 37 of Set 1 | ixtapa
# Processing Record 38 of Set 1 | saldanha
# Processing Record 39 of Set 1 | kodiak
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | pyshchug
# Processing Record 42 of Set 1 | saint-philippe
# Processing Record 43 of Set 1 | saint george
# Processing Record 44 of Set 1 | mar del plata
# Processing Record 45 of Set 1 | bilibino
# Processing Record 46 of Set 1 | paraiso
# Processing Record 47 of Set 1 | nylstroom
# City not found. Skipping...
# Processing Record 48 of Set 1 | nemuro
# Processing Record 49 of Set 1 | portland
# Processing Record 50 of Set 1 | butaritari
# Processing Record 1 of Set 2 | atuona
# Processing Record 2 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 2 | arlit
# Processing Record 4 of Set 2 | chuy
# Processing Record 5 of Set 2 | kargopol
# Processing Record 6 of Set 2 | hobart
# Processing Record 7 of Set 2 | whitehorse
# Processing Record 8 of Set 2 | guantanamo
# Processing Record 9 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 2 | bambous virieux
# Processing Record 11 of Set 2 | mahebourg
# Processing Record 12 of Set 2 | necochea
# Processing Record 13 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 2 | mount isa
# Processing Record 15 of Set 2 | vitina
# Processing Record 16 of Set 2 | anadyr
# Processing Record 17 of Set 2 | lebu
# Processing Record 18 of Set 2 | mount gambier
# Processing Record 19 of Set 2 | saint-joseph
# Processing Record 20 of Set 2 | luderitz
# Processing Record 21 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 2 | salalah
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | vaini
# Processing Record 25 of Set 2 | san juan
# Processing Record 26 of Set 2 | wattegama
# Processing Record 27 of Set 2 | yellowknife
# Processing Record 28 of Set 2 | margate
# Processing Record 29 of Set 2 | kayerkan
# Processing Record 30 of Set 2 | talnakh
# Processing Record 31 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 2 | san marcos
# Processing Record 33 of Set 2 | high level
# Processing Record 34 of Set 2 | caravelas
# Processing Record 35 of Set 2 | sioux lookout
# Processing Record 36 of Set 2 | dikson
# Processing Record 37 of Set 2 | avera
# Processing Record 38 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 2 | saskylakh
# Processing Record 40 of Set 2 | albany
# Processing Record 41 of Set 2 | wanaka
# Processing Record 42 of Set 2 | aklavik
# Processing Record 43 of Set 2 | upernavik
# Processing Record 44 of Set 2 | coronon
# Processing Record 45 of Set 2 | nouadhibou
# Processing Record 46 of Set 2 | martapura
# Processing Record 47 of Set 2 | vigrestad
# Processing Record 48 of Set 2 | bubaque
# Processing Record 49 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 2 | tura
# Processing Record 1 of Set 3 | wamba
# Processing Record 2 of Set 3 | najran
# Processing Record 3 of Set 3 | geraldton
# Processing Record 4 of Set 3 | oudtshoorn
# Processing Record 5 of Set 3 | ozinki
# Processing Record 6 of Set 3 | dingzhou
# Processing Record 7 of Set 3 | korogwe
# City not found. Skipping...
# Processing Record 8 of Set 3 | inhapim
# Processing Record 9 of Set 3 | port elizabeth
# Processing Record 10 of Set 3 | kapaa
# Processing Record 11 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 12 of Set 3 | burns lake
# Processing Record 13 of Set 3 | lompoc
# Processing Record 14 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 3 | hithadhoo
# Processing Record 16 of Set 3 | aku
# Processing Record 17 of Set 3 | arraial do cabo
# Processing Record 18 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 3 | east london
# Processing Record 20 of Set 3 | iqaluit
# Processing Record 21 of Set 3 | broome
# Processing Record 22 of Set 3 | ribeira grande
# Processing Record 23 of Set 3 | victoria
# Processing Record 24 of Set 3 | tototlan
# Processing Record 25 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 3 | ust-maya
# Processing Record 27 of Set 3 | pozo colorado
# Processing Record 28 of Set 3 | new norfolk
# Processing Record 29 of Set 3 | lodja
# Processing Record 30 of Set 3 | qaanaaq
# Processing Record 31 of Set 3 | port blair
# Processing Record 32 of Set 3 | airai
# Processing Record 33 of Set 3 | champerico
# Processing Record 34 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 36 of Set 3 | henties bay
# Processing Record 37 of Set 3 | sao joao da barra
# Processing Record 38 of Set 3 | katsuura
# Processing Record 39 of Set 3 | dingle
# Processing Record 40 of Set 3 | fairbanks
# Processing Record 41 of Set 3 | phangnga
# Processing Record 42 of Set 3 | hofn
# Processing Record 43 of Set 3 | virden
# Processing Record 44 of Set 3 | emerald
# Processing Record 45 of Set 3 | sug-aksy
# City not found. Skipping...
# Processing Record 46 of Set 3 | ahipara
# Processing Record 47 of Set 3 | xinzhou
# Processing Record 48 of Set 3 | wyndham
# Processing Record 49 of Set 3 | mandera
# Processing Record 50 of Set 3 | caborca
# Processing Record 1 of Set 4 | saint anthony
# Processing Record 2 of Set 4 | nanortalik
# Processing Record 3 of Set 4 | faanui
# Processing Record 4 of Set 4 | keetmanshoop
# Processing Record 5 of Set 4 | trairi
# Processing Record 6 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 7 of Set 4 | tasiilaq
# Processing Record 8 of Set 4 | corrientes
# Processing Record 9 of Set 4 | verkhoyansk
# Processing Record 10 of Set 4 | port-de-paix
# City not found. Skipping...
# Processing Record 11 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 4 | port hardy
# Processing Record 13 of Set 4 | narsaq
# Processing Record 14 of Set 4 | aswan
# Processing Record 15 of Set 4 | okhotsk
# Processing Record 16 of Set 4 | ulundi
# Processing Record 17 of Set 4 | kenai
# Processing Record 18 of Set 4 | khatanga
# Processing Record 19 of Set 4 | ust-ishim
# Processing Record 20 of Set 4 | vestmannaeyjar
# Processing Record 21 of Set 4 | hirado
# Processing Record 22 of Set 4 | cabo san lucas
# Processing Record 23 of Set 4 | banyo
# Processing Record 24 of Set 4 | lavrentiya
# Processing Record 25 of Set 4 | rockport
# Processing Record 26 of Set 4 | maryville
# Processing Record 27 of Set 4 | beringovskiy
# Processing Record 28 of Set 4 | san quintin
# Processing Record 29 of Set 4 | yulara
# Processing Record 30 of Set 4 | tuktoyaktuk
# Processing Record 31 of Set 4 | praia da vitoria
# Processing Record 32 of Set 4 | kieta
# Processing Record 33 of Set 4 | chokurdakh
# Processing Record 34 of Set 4 | cidreira
# Processing Record 35 of Set 4 | puerto madryn
# Processing Record 36 of Set 4 | oksbol
# Processing Record 37 of Set 4 | shihezi
# Processing Record 38 of Set 4 | nioro
# Processing Record 39 of Set 4 | ugoofaaru
# Processing Record 40 of Set 4 | esperance
# Processing Record 41 of Set 4 | great yarmouth
# Processing Record 42 of Set 4 | linhares
# Processing Record 43 of Set 4 | yazd
# Processing Record 44 of Set 4 | severo-kurilsk
# Processing Record 45 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 4 | alugan
# Processing Record 47 of Set 4 | provideniya
# Processing Record 48 of Set 4 | plettenberg bay
# Processing Record 49 of Set 4 | kabalo
# Processing Record 50 of Set 4 | kaitangata
# Processing Record 1 of Set 5 | kathmandu
# Processing Record 2 of Set 5 | itupiranga
# Processing Record 3 of Set 5 | adrar
# Processing Record 4 of Set 5 | fuyang
# Processing Record 5 of Set 5 | pinega
# Processing Record 6 of Set 5 | skibbereen
# Processing Record 7 of Set 5 | georgetown
# Processing Record 8 of Set 5 | ouadda
# Processing Record 9 of Set 5 | deming
# Processing Record 10 of Set 5 | luce
# Processing Record 11 of Set 5 | carnarvon
# Processing Record 12 of Set 5 | la ronge
# Processing Record 13 of Set 5 | mecca
# Processing Record 14 of Set 5 | celestun
# Processing Record 15 of Set 5 | kutum
# Processing Record 16 of Set 5 | laguna
# Processing Record 17 of Set 5 | biloela
# Processing Record 18 of Set 5 | saint-jean-de-maurienne
# Processing Record 19 of Set 5 | pangnirtung
# Processing Record 20 of Set 5 | ammon
# Processing Record 21 of Set 5 | vityazevo
# Processing Record 22 of Set 5 | alice springs
# Processing Record 23 of Set 5 | ibra
# Processing Record 24 of Set 5 | vitoria da conquista
# Processing Record 25 of Set 5 | north bend
# Processing Record 26 of Set 5 | yeniseysk
# Processing Record 27 of Set 5 | kannad
# Processing Record 28 of Set 5 | destin
# Processing Record 29 of Set 5 | pitimbu
# Processing Record 30 of Set 5 | along
# Processing Record 31 of Set 5 | novo aripuana
# Processing Record 32 of Set 5 | deputatskiy
# Processing Record 33 of Set 5 | point pedro
# Processing Record 34 of Set 5 | pevek
# Processing Record 35 of Set 5 | hebi
# Processing Record 36 of Set 5 | dillon
# Processing Record 37 of Set 5 | puerto carreno
# Processing Record 38 of Set 5 | mahon
# Processing Record 39 of Set 5 | coahuayana
# Processing Record 40 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 41 of Set 5 | piste
# Processing Record 42 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 43 of Set 5 | ilulissat
# Processing Record 44 of Set 5 | pisco
# Processing Record 45 of Set 5 | tuatapere
# Processing Record 46 of Set 5 | bagasara
# City not found. Skipping...
# Processing Record 47 of Set 5 | kulu
# Processing Record 48 of Set 5 | klyuchi
# Processing Record 49 of Set 5 | ulladulla
# Processing Record 50 of Set 5 | saint-francois
# Processing Record 1 of Set 6 | avarua
# Processing Record 2 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 6 | parras
# City not found. Skipping...
# Processing Record 4 of Set 6 | batemans bay
# Processing Record 5 of Set 6 | hasaki
# Processing Record 6 of Set 6 | tarakan
# Processing Record 7 of Set 6 | san francisco del mar
# Processing Record 8 of Set 6 | iracoubo
# Processing Record 9 of Set 6 | tautira
# Processing Record 10 of Set 6 | port elgin
# Processing Record 11 of Set 6 | turbat
# Processing Record 12 of Set 6 | port moresby
# Processing Record 13 of Set 6 | coquimbo
# Processing Record 14 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 6 | strangnas
# Processing Record 16 of Set 6 | fort-shevchenko
# Processing Record 17 of Set 6 | orlik
# Processing Record 18 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 6 | nanyang
# Processing Record 20 of Set 6 | shubarshi
# Processing Record 21 of Set 6 | auki
# Processing Record 22 of Set 6 | ostrovnoy
# Processing Record 23 of Set 6 | nichinan
# Processing Record 24 of Set 6 | east retford
# City not found. Skipping...
# Processing Record 25 of Set 6 | cherskiy
# Processing Record 26 of Set 6 | manadhoo
# Processing Record 27 of Set 6 | batagay-alyta
# Processing Record 28 of Set 6 | kyzyl-suu
# Processing Record 29 of Set 6 | haapiti
# Processing Record 30 of Set 6 | sao gabriel da cachoeira
# Processing Record 31 of Set 6 | tiksi
# Processing Record 32 of Set 6 | burica
# City not found. Skipping...
# Processing Record 33 of Set 6 | nikolskoye
# Processing Record 34 of Set 6 | harnosand
# Processing Record 35 of Set 6 | ostersund
# Processing Record 36 of Set 6 | yunjinghong
# City not found. Skipping...
# Processing Record 37 of Set 6 | aguimes
# Processing Record 38 of Set 6 | vila
# Processing Record 39 of Set 6 | usak
# Processing Record 40 of Set 6 | olavarria
# Processing Record 41 of Set 6 | ban nahin
# Processing Record 42 of Set 6 | cajazeiras
# Processing Record 43 of Set 6 | xichang
# Processing Record 44 of Set 6 | luganville
# Processing Record 45 of Set 6 | manzhouli
# Processing Record 46 of Set 6 | ponta do sol
# Processing Record 47 of Set 6 | padang
# Processing Record 48 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 6 | yairipok
# Processing Record 1 of Set 7 | jackson
# Processing Record 2 of Set 7 | svetlaya
# Processing Record 3 of Set 7 | dunedin
# Processing Record 4 of Set 7 | tual
# Processing Record 5 of Set 7 | kuminskiy
# Processing Record 6 of Set 7 | vrangel
# Processing Record 7 of Set 7 | coatzintla
# Processing Record 8 of Set 7 | kazanskoye
# Processing Record 9 of Set 7 | grand-santi
# Processing Record 10 of Set 7 | sabha
# Processing Record 11 of Set 7 | baruun-urt
# Processing Record 12 of Set 7 | grindavik
# Processing Record 13 of Set 7 | solwezi
# Processing Record 14 of Set 7 | faya
# Processing Record 15 of Set 7 | iquique
# Processing Record 16 of Set 7 | ulaangom
# Processing Record 17 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 18 of Set 7 | nome
# Processing Record 19 of Set 7 | kasama
# Processing Record 20 of Set 7 | alofi
# Processing Record 21 of Set 7 | gainesville
# Processing Record 22 of Set 7 | kirensk
# Processing Record 23 of Set 7 | rocha
# Processing Record 24 of Set 7 | roald
# Processing Record 25 of Set 7 | prattville
# Processing Record 26 of Set 7 | aykhal
# Processing Record 27 of Set 7 | kiruna
# Processing Record 28 of Set 7 | makasar
# Processing Record 29 of Set 7 | borovskoy
# Processing Record 30 of Set 7 | pervomayskoye
# Processing Record 31 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 32 of Set 7 | omboue
# Processing Record 33 of Set 7 | tongliao
# Processing Record 34 of Set 7 | severo-yeniseyskiy
# Processing Record 35 of Set 7 | misasi
# Processing Record 36 of Set 7 | malkangiri
# Processing Record 37 of Set 7 | jardim
# Processing Record 38 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 7 | vila franca do campo
# Processing Record 40 of Set 7 | guerrero negro
# Processing Record 41 of Set 7 | krasnoye
# Processing Record 42 of Set 7 | bandarbeyla
# Processing Record 43 of Set 7 | marsabit
# Processing Record 44 of Set 7 | kavaratti
# Processing Record 45 of Set 7 | magrath
# Processing Record 46 of Set 7 | lebanon
# Processing Record 47 of Set 7 | loreto
# Processing Record 48 of Set 7 | minab
# Processing Record 49 of Set 7 | russell
# Processing Record 50 of Set 7 | nandura
# Processing Record 1 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 8 | rio grande
# Processing Record 3 of Set 8 | lensk
# Processing Record 4 of Set 8 | harlingen
# Processing Record 5 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 8 | sambava
# Processing Record 7 of Set 8 | chalus
# Processing Record 8 of Set 8 | nabire
# Processing Record 9 of Set 8 | boyabat
# Processing Record 10 of Set 8 | krasnoselkup
# Processing Record 11 of Set 8 | nazarovo
# Processing Record 12 of Set 8 | banda aceh
# Processing Record 13 of Set 8 | port-cartier
# Processing Record 14 of Set 8 | belaya gora
# Processing Record 15 of Set 8 | richards bay
# Processing Record 16 of Set 8 | palmer
# Processing Record 17 of Set 8 | zonguldak
# Processing Record 18 of Set 8 | ouricuri
# Processing Record 19 of Set 8 | paka
# Processing Record 20 of Set 8 | porto novo
# Processing Record 21 of Set 8 | pemex
# Processing Record 22 of Set 8 | port macquarie
# Processing Record 23 of Set 8 | coolum beach
# Processing Record 24 of Set 8 | codrington
# Processing Record 25 of Set 8 | beira
# Processing Record 26 of Set 8 | norman wells
# Processing Record 27 of Set 8 | isangel
# Processing Record 28 of Set 8 | jining
# Processing Record 29 of Set 8 | marshall
# Processing Record 30 of Set 8 | amapa
# Processing Record 31 of Set 8 | kinsale
# Processing Record 32 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 8 | mbuguni
# Processing Record 34 of Set 8 | asyut
# Processing Record 35 of Set 8 | frederikshavn
# Processing Record 36 of Set 8 | mahibadhoo
# Processing Record 37 of Set 8 | dasoguz
# Processing Record 38 of Set 8 | nanakuli
# Processing Record 39 of Set 8 | harper
# Processing Record 40 of Set 8 | eureka
# Processing Record 41 of Set 8 | constitucion
# Processing Record 42 of Set 8 | yueyang
# Processing Record 43 of Set 8 | kemi
# Processing Record 44 of Set 8 | fortuna
# Processing Record 45 of Set 8 | sinop
# Processing Record 46 of Set 8 | solnechnyy
# Processing Record 47 of Set 8 | kruisfontein
# Processing Record 48 of Set 8 | woodward
# Processing Record 49 of Set 8 | dicabisagan
# Processing Record 50 of Set 8 | bloomfield
# Processing Record 1 of Set 9 | indramayu
# Processing Record 2 of Set 9 | eydhafushi
# Processing Record 3 of Set 9 | jacareacanga
# Processing Record 4 of Set 9 | cayenne
# Processing Record 5 of Set 9 | dourados
# Processing Record 6 of Set 9 | sendhwa
# Processing Record 7 of Set 9 | chulym
# Processing Record 8 of Set 9 | lexington
# Processing Record 9 of Set 9 | sattahip
# Processing Record 10 of Set 9 | kavieng
# Processing Record 11 of Set 9 | conway
# Processing Record 12 of Set 9 | the hammocks
# Processing Record 13 of Set 9 | roma
# Processing Record 14 of Set 9 | zhanaozen
# Processing Record 15 of Set 9 | souillac
# Processing Record 16 of Set 9 | wajima
# Processing Record 17 of Set 9 | miraflores
# Processing Record 18 of Set 9 | san cristobal
# Processing Record 19 of Set 9 | san rafael
# Processing Record 20 of Set 9 | kenora
# Processing Record 21 of Set 9 | zaysan
# Processing Record 22 of Set 9 | bossembele
# City not found. Skipping...
# Processing Record 23 of Set 9 | abasolo
# Processing Record 24 of Set 9 | sudbury
# Processing Record 25 of Set 9 | barra velha
# Processing Record 26 of Set 9 | nara
# Processing Record 27 of Set 9 | vardo
# Processing Record 28 of Set 9 | deh rawud
# City not found. Skipping...
# Processing Record 29 of Set 9 | sola
# Processing Record 30 of Set 9 | manggar
# Processing Record 31 of Set 9 | clyde river
# Processing Record 32 of Set 9 | lorengau
# Processing Record 33 of Set 9 | sumbawanga
# Processing Record 34 of Set 9 | bengkulu
# Processing Record 35 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 36 of Set 9 | charlestown
# Processing Record 37 of Set 9 | sobolevo
# Processing Record 38 of Set 9 | verkhnevilyuysk
# Processing Record 39 of Set 9 | longyearbyen
# Processing Record 40 of Set 9 | butte
# Processing Record 41 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 42 of Set 9 | griffith
# Processing Record 43 of Set 9 | baghdad
# Processing Record 44 of Set 9 | chapayevka
# Processing Record 45 of Set 9 | vacaria
# Processing Record 46 of Set 9 | itajuba
# Processing Record 47 of Set 9 | quelimane
# Processing Record 48 of Set 9 | juelsminde
# Processing Record 49 of Set 9 | veraval
# Processing Record 50 of Set 9 | marzuq
# Processing Record 1 of Set 10 | nelson bay
# Processing Record 2 of Set 10 | weymouth
# Processing Record 3 of Set 10 | kahului
# Processing Record 4 of Set 10 | naryan-mar
# Processing Record 5 of Set 10 | stephenville
# Processing Record 6 of Set 10 | chenzhou
# Processing Record 7 of Set 10 | hirara
# Processing Record 8 of Set 10 | yining
# Processing Record 9 of Set 10 | gouyave
# Processing Record 10 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 10 | praia
# Processing Record 12 of Set 10 | corinto
# Processing Record 13 of Set 10 | valparaiso
# Processing Record 14 of Set 10 | dourbali
# Processing Record 15 of Set 10 | sungaipenuh
# Processing Record 16 of Set 10 | lanzhot
# Processing Record 17 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 18 of Set 10 | eslov
# Processing Record 19 of Set 10 | hovd
# Processing Record 20 of Set 10 | rio gallegos
# Processing Record 21 of Set 10 | wampusirpi
# City not found. Skipping...
# Processing Record 22 of Set 10 | sao filipe
# Processing Record 23 of Set 10 | pomabamba
# Processing Record 24 of Set 10 | chicama
# Processing Record 25 of Set 10 | tondano
# Processing Record 26 of Set 10 | moron
# Processing Record 27 of Set 10 | nipawin
# Processing Record 28 of Set 10 | melito di porto salvo
# Processing Record 29 of Set 10 | coetupo
# City not found. Skipping...
# Processing Record 30 of Set 10 | prince rupert
# Processing Record 31 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 32 of Set 10 | pitalito
# Processing Record 33 of Set 10 | taltal
# Processing Record 34 of Set 10 | axim
# Processing Record 35 of Set 10 | chopinzinho
# Processing Record 36 of Set 10 | torbay
# Processing Record 37 of Set 10 | tilichiki
# Processing Record 38 of Set 10 | egvekinot
# Processing Record 39 of Set 10 | paamiut
# Processing Record 40 of Set 10 | saint pete beach
# Processing Record 41 of Set 10 | kanniyakumari
# Processing Record 42 of Set 10 | urucui
# Processing Record 43 of Set 10 | magnolia
# Processing Record 44 of Set 10 | poum
# Processing Record 45 of Set 10 | itarema
# Processing Record 46 of Set 10 | livingston
# Processing Record 47 of Set 10 | pavlogradka
# Processing Record 48 of Set 10 | teya
# Processing Record 49 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 50 of Set 10 | yelizovo
# Processing Record 1 of Set 11 | bathsheba
# Processing Record 2 of Set 11 | goderich
# Processing Record 3 of Set 11 | rawson
# Processing Record 4 of Set 11 | mgandu
# Processing Record 5 of Set 11 | oranjemund
# Processing Record 6 of Set 11 | traverse city
# Processing Record 7 of Set 11 | mumford
# Processing Record 8 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 9 of Set 11 | bilma
# Processing Record 10 of Set 11 | ust-ilimsk
# Processing Record 11 of Set 11 | ossora
# Processing Record 12 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 13 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 11 | klaksvik
# Processing Record 15 of Set 11 | nicoya
# Processing Record 16 of Set 11 | kasongo-lunda
# Processing Record 17 of Set 11 | maloyaz
# City not found. Skipping...
# Processing Record 18 of Set 11 | edgewater
# Processing Record 19 of Set 11 | lumeje
# Processing Record 20 of Set 11 | ilhabela
# Processing Record 21 of Set 11 | vilhena
# Processing Record 22 of Set 11 | ust-kuyga
# Processing Record 23 of Set 11 | alirajpur
# Processing Record 24 of Set 11 | kanevskaya
# Processing Record 25 of Set 11 | yugo-kamskiy
# Processing Record 26 of Set 11 | barranca
# Processing Record 27 of Set 11 | lucea
# Processing Record 28 of Set 11 | kamiiso
# Processing Record 29 of Set 11 | evensk
# Processing Record 30 of Set 11 | bandar
# Processing Record 31 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 32 of Set 11 | bairiki
# Processing Record 33 of Set 11 | meulaboh
# Processing Record 34 of Set 11 | hami
# Processing Record 35 of Set 11 | tazovskiy
# Processing Record 36 of Set 11 | christchurch
# Processing Record 37 of Set 11 | pedro juan caballero
# Processing Record 38 of Set 11 | sfantu gheorghe
# Processing Record 39 of Set 11 | uruzgan
# Processing Record 40 of Set 11 | zhangjiakou
# Processing Record 41 of Set 11 | shelburne
# Processing Record 42 of Set 11 | srandakan
# Processing Record 43 of Set 11 | kikwit
# Processing Record 44 of Set 11 | maravatio
# Processing Record 45 of Set 11 | sangar
# Processing Record 46 of Set 11 | viedma
# Processing Record 47 of Set 11 | san patricio
# Processing Record 48 of Set 11 | matata
# Processing Record 49 of Set 11 | zschopau
# Processing Record 50 of Set 11 | santa rosa
# Processing Record 1 of Set 12 | taksimo
# Processing Record 2 of Set 12 | sorland
# Processing Record 3 of Set 12 | aliwal north
# Processing Record 4 of Set 12 | pringsewu
# Processing Record 5 of Set 12 | abha
# Processing Record 6 of Set 12 | moree
# Processing Record 7 of Set 12 | monte patria
# Processing Record 8 of Set 12 | rosario
# Processing Record 9 of Set 12 | yuci
# Processing Record 10 of Set 12 | yanam
# Processing Record 11 of Set 12 | vila velha
# Processing Record 12 of Set 12 | chulman
# Processing Record 13 of Set 12 | bandarban
# Processing Record 14 of Set 12 | bulgan
# Processing Record 15 of Set 12 | maloshuyka
# City not found. Skipping...
# Processing Record 16 of Set 12 | flin flon
# Processing Record 17 of Set 12 | huarmey
# Processing Record 18 of Set 12 | inirida
# Processing Record 19 of Set 12 | bay saint louis
# Processing Record 20 of Set 12 | lolodorf
# Processing Record 21 of Set 12 | southbridge
# Processing Record 22 of Set 12 | kamenka
# Processing Record 23 of Set 12 | provost
# Processing Record 24 of Set 12 | jambi
# Processing Record 25 of Set 12 | saint-georges
# Processing Record 26 of Set 12 | paragominas
# Processing Record 27 of Set 12 | manzil jamil
# City not found. Skipping...
# Processing Record 28 of Set 12 | mahaicony
# City not found. Skipping...
# Processing Record 29 of Set 12 | jizan
# Processing Record 30 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 12 | dzhebariki-khaya
# Processing Record 32 of Set 12 | monywa
# Processing Record 33 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 34 of Set 12 | srednekolymsk
# Processing Record 35 of Set 12 | xuzhou
# Processing Record 36 of Set 12 | cockburn town
# Processing Record 37 of Set 12 | urdoma
# Processing Record 38 of Set 12 | dutse
# Processing Record 39 of Set 12 | launceston
# Processing Record 40 of Set 12 | lokhvytsya
# Processing Record 41 of Set 12 | ciudad bolivar
# Processing Record 42 of Set 12 | linguere
# Processing Record 43 of Set 12 | suzu
# City not found. Skipping...
# Processing Record 44 of Set 12 | santa maria
# Processing Record 45 of Set 12 | vostok
# Processing Record 46 of Set 12 | forest grove
# Processing Record 47 of Set 12 | umea
# Processing Record 48 of Set 12 | arman
# Processing Record 49 of Set 12 | bereda
# Processing Record 50 of Set 12 | xingyi
# Processing Record 1 of Set 13 | nacala
# Processing Record 2 of Set 13 | panaba
# Processing Record 3 of Set 13 | dera bugti
# Processing Record 4 of Set 13 | wuzhou
# Processing Record 5 of Set 13 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 13 | tecoanapa
# Processing Record 7 of Set 13 | tucuma
# Processing Record 8 of Set 13 | trogir
# Processing Record 9 of Set 13 | brandon
# Processing Record 10 of Set 13 | vestmanna
# Processing Record 11 of Set 13 | dakar
# Processing Record 12 of Set 13 | tunduma
# Processing Record 13 of Set 13 | tenenkou
# Processing Record 14 of Set 13 | san bartolome de tirajana
# Processing Record 15 of Set 13 | milcovul
# Processing Record 16 of Set 13 | elko
# Processing Record 17 of Set 13 | ahuimanu
# Processing Record 18 of Set 13 | mae hong son
# Processing Record 19 of Set 13 | strezhevoy
# Processing Record 20 of Set 13 | te anau
# Processing Record 21 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 22 of Set 13 | oeiras
# Processing Record 23 of Set 13 | acarau
# Processing Record 24 of Set 13 | timbiqui
# Processing Record 25 of Set 13 | jaciara
# Processing Record 26 of Set 13 | novikovo
# Processing Record 27 of Set 13 | ust-nera
# Processing Record 28 of Set 13 | bijie
# Processing Record 29 of Set 13 | brabova
# Processing Record 30 of Set 13 | urumqi
# Processing Record 31 of Set 13 | gallup
# Processing Record 32 of Set 13 | varhaug
# Processing Record 33 of Set 13 | fort nelson
# Processing Record 34 of Set 13 | krasnyy chikoy
# Processing Record 35 of Set 13 | port-gentil
# Processing Record 36 of Set 13 | usinsk
# Processing Record 37 of Set 13 | singaraja
# Processing Record 38 of Set 13 | hambantota
# Processing Record 39 of Set 13 | uthal
# Processing Record 40 of Set 13 | roura
# Processing Record 41 of Set 13 | buraydah
# Processing Record 42 of Set 13 | peniche
# Processing Record 43 of Set 13 | shenjiamen
# Processing Record 44 of Set 13 | gagarin
# Processing Record 45 of Set 13 | nyimba
# Processing Record 46 of Set 13 | qom
# Processing Record 47 of Set 13 | lasa
# Processing Record 48 of Set 13 | road town
# Processing Record 49 of Set 13 | pemangkat
# Processing Record 50 of Set 13 | kailua
# Processing Record 1 of Set 14 | salinas
# Processing Record 2 of Set 14 | korhogo
# Processing Record 3 of Set 14 | hamilton
# Processing Record 4 of Set 14 | mkushi
# Processing Record 5 of Set 14 | barrancabermeja
# Processing Record 6 of Set 14 | kismayo
# Processing Record 7 of Set 14 | nalut
# Processing Record 8 of Set 14 | riyadh
# Processing Record 9 of Set 14 | walvis bay
# Processing Record 10 of Set 14 | sibu
# Processing Record 11 of Set 14 | antalaha
# Processing Record 12 of Set 14 | salinopolis
# Processing Record 13 of Set 14 | callaway
# Processing Record 14 of Set 14 | nishihara
# Processing Record 15 of Set 14 | kapoeta
# Processing Record 16 of Set 14 | namatanai
# Processing Record 17 of Set 14 | pachalum
# Processing Record 18 of Set 14 | altus
# Processing Record 19 of Set 14 | vung tau
# Processing Record 20 of Set 14 | havre-saint-pierre
# Processing Record 21 of Set 14 | banmo
# City not found. Skipping...
# Processing Record 22 of Set 14 | kidal
# Processing Record 23 of Set 14 | sergeyevka
# Processing Record 24 of Set 14 | yar-sale
# Processing Record 25 of Set 14 | isilkul
# Processing Record 26 of Set 14 | los llanos de aridane
# Processing Record 27 of Set 14 | leningradskiy
# Processing Record 28 of Set 14 | poya
# Processing Record 29 of Set 14 | cam ranh
# Processing Record 30 of Set 14 | amursk
# Processing Record 31 of Set 14 | excelsior springs
# Processing Record 32 of Set 14 | xinqing
# Processing Record 33 of Set 14 | inhambane
# Processing Record 34 of Set 14 | hvammstangi
# City not found. Skipping...
# Processing Record 35 of Set 14 | kodinsk
# Processing Record 36 of Set 14 | rundu
# Processing Record 37 of Set 14 | valdivia
# Processing Record 38 of Set 14 | makakilo city
# Processing Record 39 of Set 14 | broken hill
# Processing Record 40 of Set 14 | huilong
# Processing Record 41 of Set 14 | mehran
# Processing Record 42 of Set 14 | brae
# Processing Record 43 of Set 14 | smithers
# Processing Record 44 of Set 14 | honningsvag
# Processing Record 45 of Set 14 | brooks
# Processing Record 46 of Set 14 | thaton
# Processing Record 47 of Set 14 | elliot lake
# Processing Record 48 of Set 14 | pardina
# Processing Record 49 of Set 14 | owando
# Processing Record 50 of Set 14 | sabang
# Processing Record 1 of Set 15 | bela
# Processing Record 2 of Set 15 | touros
# Processing Record 3 of Set 15 | lufilufi
# Processing Record 4 of Set 15 | ankazobe
# Processing Record 5 of Set 15 | santander
# Processing Record 6 of Set 15 | daru
# Processing Record 7 of Set 15 | west linton
# Processing Record 8 of Set 15 | jalu
# Processing Record 9 of Set 15 | lipari
# Processing Record 10 of Set 15 | cortez
# Processing Record 11 of Set 15 | nur
# Processing Record 12 of Set 15 | summerville
# Processing Record 13 of Set 15 | zhezkazgan
# Processing Record 14 of Set 15 | ozgon
# City not found. Skipping...
# Processing Record 15 of Set 15 | katangli
# Processing Record 16 of Set 15 | bintulu
# Processing Record 17 of Set 15 | palu
# Processing Record 18 of Set 15 | port lincoln
# Processing Record 19 of Set 15 | uman
# Processing Record 20 of Set 15 | waterloo
# Processing Record 21 of Set 15 | pecos
# Processing Record 22 of Set 15 | say
# Processing Record 23 of Set 15 | aksu
# Processing Record 24 of Set 15 | korla
# Processing Record 25 of Set 15 | buique
# Processing Record 26 of Set 15 | emilio carranza
# Processing Record 27 of Set 15 | dehloran
# Processing Record 28 of Set 15 | reo
# Processing Record 29 of Set 15 | babayurt
# Processing Record 30 of Set 15 | santiago
# Processing Record 31 of Set 15 | bheramara
# Processing Record 32 of Set 15 | naftah
# City not found. Skipping...
# Processing Record 33 of Set 15 | bemidji
# Processing Record 34 of Set 15 | andenes
# Processing Record 35 of Set 15 | atar
# Processing Record 36 of Set 15 | rio grande city
# Processing Record 37 of Set 15 | hualmay
# Processing Record 38 of Set 15 | ranfurly
# Processing Record 39 of Set 15 | keti bandar
# Processing Record 40 of Set 15 | vitim
# Processing Record 41 of Set 15 | cairns
# Processing Record 42 of Set 15 | bila krynytsya
# Processing Record 43 of Set 15 | fairview
# Processing Record 44 of Set 15 | biabou
# Processing Record 45 of Set 15 | villarrica
# Processing Record 46 of Set 15 | rongcheng
# Processing Record 47 of Set 15 | kashi
# Processing Record 48 of Set 15 | ormara
# Processing Record 49 of Set 15 | calama
# Processing Record 50 of Set 15 | gigmoto
# Processing Record 1 of Set 16 | marsh harbour
# Processing Record 2 of Set 16 | onguday
# Processing Record 3 of Set 16 | badarwas
# Processing Record 4 of Set 16 | itoman
# Processing Record 5 of Set 16 | skagastrond
# City not found. Skipping...
# Processing Record 6 of Set 16 | xining
# Processing Record 7 of Set 16 | thinadhoo
# Processing Record 8 of Set 16 | nevers
# Processing Record 9 of Set 16 | tessalit
# Processing Record 10 of Set 16 | dawlatabad
# Processing Record 11 of Set 16 | sao felix do xingu
# Processing Record 12 of Set 16 | gerede
# Processing Record 13 of Set 16 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 16 | urengoy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 696

# %%
# 7. Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Olafsvik  64.89  -23.71     48.65        83          96       19.95
# 1        Ushuaia -54.80  -68.30     42.80        70          40       10.29
# 2       Zhigansk  66.77  123.37     57.15        58          31       11.79
# 3         Bethel  41.37  -73.41     75.99        88          90        4.70
# 4           Hilo  19.73 -155.09     71.60        78          75        4.70
# 5        Rikitea -23.12 -134.97     72.57        76          53       11.54
# 6  Palaia Fokaia  37.72   23.95     93.00        31          20       20.80
# 7      Busselton -33.65  115.33     48.00        98          42        8.12
# 8     Santa Cruz -17.80  -63.17     86.00        39           0       14.99
# 9        Husavik  66.04  -17.34     55.40        76          90       11.41
#
#   Current Description Country                 Date
# 0              Clouds      IS  2020-08-02 15:23:13
# 1              Clouds      AR  2020-08-02 15:23:09
# 2              Clouds      RU  2020-08-02 15:24:25
# 3              Clouds      US  2020-08-02 15:24:25
# 4              Clouds      US  2020-08-02 15:22:42
# 5              Clouds      PF  2020-08-02 15:24:25
# 6              Clouds      GR  2020-08-02 15:24:25
# 7                Rain      AU  2020-08-02 15:24:25
# 8               Clear      BO  2020-08-02 15:22:27
# 9              Clouds      IS  2020-08-02 15:24:21

# %%
# reorder the columns as City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, and Wind Speed
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       Olafsvik      IS  64.89  -23.71     48.65        83          96
# 1        Ushuaia      AR -54.80  -68.30     42.80        70          40
# 2       Zhigansk      RU  66.77  123.37     57.15        58          31
# 3         Bethel      US  41.37  -73.41     75.99        88          90
# 4           Hilo      US  19.73 -155.09     71.60        78          75
# 5        Rikitea      PF -23.12 -134.97     72.57        76          53
# 6  Palaia Fokaia      GR  37.72   23.95     93.00        31          20
# 7      Busselton      AU -33.65  115.33     48.00        98          42
# 8     Santa Cruz      BO -17.80  -63.17     86.00        39           0
# 9        Husavik      IS  66.04  -17.34     55.40        76          90
#
#    Wind Speed Current Description
# 0       19.95              Clouds
# 1       10.29              Clouds
# 2       11.79              Clouds
# 3        4.70              Clouds
# 4        4.70              Clouds
# 5       11.54              Clouds
# 6       20.80              Clouds
# 7        8.12                Rain
# 8       14.99               Clear
# 9       11.41              Clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
